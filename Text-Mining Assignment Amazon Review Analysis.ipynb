# %%
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/dp/B076B8G5D8/ref=sr_1_1?dchild=1&keywords=boya&qid=1597827343&sr=8-1"

# %%
url
# Out:
# 'https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/dp/B076B8G5D8/ref=sr_1_1?dchild=1&keywords=boya&qid=1597827343&sr=8-1'

# %%
header={'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/77.0.3865.90 Safari/537.36'}

# %%
cookie={}

# %%
def Searchasin(asin):
    url="https://www.amazon.in/dp/"+asin
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
def Searchreviews(review_link):
    url="https://www.amazon.in"+review_link
    print(url)
    page=requests.get(url,cookies=cookie,headers=header)
    if page.status_code==200:
        return page
    else:
        return "Error"

# %%
data_asin = url.split("/dp/")[1]
data_asin =  data_asin.split("/")[0]

# %%
data_asin = [data_asin]

# %%
len(data_asin)
# Out:
# 1

# %%
link=[]
for i in range(len(data_asin)):
    response=Searchasin(data_asin[i])
    soup=BeautifulSoup(response.content)
    for i in soup.findAll("a",{'data-hook':"see-all-reviews-link-foot"}):
        link.append(i['href'])
# Out:
# https://www.amazon.in/dp/B076B8G5D8

# %%
pages=50

# %%
time=[]
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-date"}):
            time.append(i.text)
# Out:
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=10
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=11
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=12
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=13
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=14
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=15
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=16
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=17
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=18
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=19
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=20
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=21
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=22
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=23
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=24
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=25
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=26
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=27
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=28
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=29
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=30
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=31
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=32
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=33
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=34
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=35
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=36
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=37
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=38
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=39
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=40
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=41
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=42
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=43
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=44
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=45
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=46
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=47
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=48
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=49

# %%
print(len(time))
print(time)
# Out:
# 500
# ['Reviewed in India on 24 November 2018', 'Reviewed in India on 25 July 2019', 'Reviewed in India on 8 May 2019', 'Reviewed in India on 5 October 2018', 'Reviewed in India on 14 February 2019', 'Reviewed in India on 12 October 2019', 'Reviewed in India on 8 August 2018', 'Reviewed in India on 25 May 2020', 'Reviewed in India on 4 July 2019', 'Reviewed in India on 21 June 2019', 'Reviewed in India on 24 November 2018', 'Reviewed in India on 25 July 2019', 'Reviewed in India on 8 May 2019', 'Reviewed in India on 5 October 2018', 'Reviewed in India on 14 February 2019', 'Reviewed in India on 12 October 2019', 'Reviewed in India on 8 August 2018', 'Reviewed in India on 25 May 2020', 'Reviewed in India on 4 July 2019', 'Reviewed in India on 21 June 2019', 'Reviewed in India on 12 February 2019', 'Reviewed in India on 2 August 2020', 'Reviewed in India on 6 July 2018', 'Reviewed in India on 16 January 2020', 'Reviewed in India on 9 May 2019', 'Reviewed in India on 28 April 2019', 'Reviewed in India on 8 July 2020', 'Reviewed in India on 31 August 2019', 'Reviewed in India on 10 February 2021', 'Reviewed in India on 27 May 2019', 'Reviewed in India on 3 August 2019', 'Reviewed in India on 8 July 2020', 'Reviewed in India on 28 October 2019', 'Reviewed in India on 16 February 2020', 'Reviewed in India on 10 June 2020', 'Reviewed in India on 25 June 2019', 'Reviewed in India on 31 December 2020', 'Reviewed in India on 14 August 2020', 'Reviewed in India on 17 August 2019', 'Reviewed in India on 23 November 2019', 'Reviewed in India on 28 August 2019', 'Reviewed in India on 7 December 2019', 'Reviewed in India on 17 September 2020', 'Reviewed in India on 23 January 2021', 'Reviewed in India on 14 August 2020', 'Reviewed in India on 30 May 2020', 'Reviewed in India on 18 February 2020', 'Reviewed in India on 2 September 2020', 'Reviewed in India on 12 August 2020', 'Reviewed in India on 30 July 2020', 'Reviewed in India on 22 September 2020', 'Reviewed in India on 25 August 2020', 'Reviewed in India on 4 November 2020', 'Reviewed in India on 25 June 2020', 'Reviewed in India on 13 January 2021', 'Reviewed in India on 23 May 2020', 'Reviewed in India on 3 September 2020', 'Reviewed in India on 28 November 2019', 'Reviewed in India on 28 August 2020', 'Reviewed in India on 8 September 2020', 'Reviewed in India on 3 April 2020', 'Reviewed in India on 1 July 2020', 'Reviewed in India on 14 March 2021', 'Reviewed in India on 5 November 2019', 'Reviewed in India on 18 October 2020', 'Reviewed in India on 11 October 2019', 'Reviewed in India on 2 September 2020', 'Reviewed in India on 7 August 2019', 'Reviewed in India on 12 June 2020', 'Reviewed in India on 25 January 2021', 'Reviewed in India on 19 August 2020', 'Reviewed in India on 19 August 2020', 'Reviewed in India on 30 September 2020', 'Reviewed in India on 16 October 2020', 'Reviewed in India on 25 February 2021', 'Reviewed in India on 15 August 2018', 'Reviewed in India on 17 November 2020', 'Reviewed in India on 22 October 2020', 'Reviewed in India on 29 September 2020', 'Reviewed in India on 1 January 2021', 'Reviewed in India on 8 September 2020', 'Reviewed in India on 9 December 2019', 'Reviewed in India on 16 January 2021', 'Reviewed in India on 16 December 2019', 'Reviewed in India on 17 September 2020', 'Reviewed in India on 25 August 2020', 'Reviewed in India on 10 February 2020', 'Reviewed in India on 17 October 2019', 'Reviewed in India on 13 September 2020', 'Reviewed in India on 28 July 2020', 'Reviewed in India on 5 July 2020', 'Reviewed in India on 5 May 2019', 'Reviewed in India on 4 July 2020', 'Reviewed in India on 7 October 2019', 'Reviewed in India on 15 May 2020', 'Reviewed in India on 19 November 2020', 'Reviewed in India on 16 September 2020', 'Reviewed in India on 22 July 2020', 'Reviewed in India on 17 May 2020', 'Reviewed in India on 23 August 2020', 'Reviewed in India on 18 October 2020', 'Reviewed in India on 29 January 2020', 'Reviewed in India on 9 October ...

# %%
names=[]
for j in range(1):
     for k in range(5):
            response=Searchreviews(link[j]+'&pageNumber='+str(k))
            soup=BeautifulSoup(response.content)
            for i in soup.find_all("span",class_='a-profile-name'):
                names.append(i.text)
# Out:
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4

# %%
cust_name=[]
for i in range(0,len(names)):
    cust_name.append(names[i])
cust_name
# Out:
# ['Digidoty',
#  'Amazon Customer',
#  'Digidoty',
#  'Shopaholic🆗',
#  'Amazon Customer',
#  'AS Peterson',
#  'Rahul',
#  'Sameer Patil',
#  'Shashank ',
#  'aryanshah',
#  'Dr. Rakesh Jain',
#  'ABHINANDAN',
#  'Digidoty',
#  'Amazon Customer',
#  'Digidoty',
#  'Shopaholic🆗',
#  'Amazon Customer',
#  'AS Peterson',
#  'Rahul',
#  'Sameer Patil',
#  'Shashank ',
#  'aryanshah',
#  'Dr. Rakesh Jain',
#  'ABHINANDAN',
#  'Digidoty',
#  'Amazon Customer',
#  'Amazon Customer',
#  'God',
#  'ravinder yadav',
#  'Rishabh Tiwari',
#  'Varifree',
#  'AMANJOT SINGH',
#  'Hardik Thakkar',
#  'Amazon Customer',
#  'Jaykumar Hankare',
#  'K Santosh',
#  'Digidoty',
#  'Amazon Customer',
#  'Ashutosh Mishra',
#  'HD',
#  'Aman Sharma',
#  'Roshan Kumar',
#  'Syed Amaan Akhtar',
#  'S',
#  'Ghalib',
#  'Gaurvendra Yadav',
#  'The Mango Couple',
#  'Shihab.H',
#  'Digidoty',
#  'Amazon Customer',
#  'Amazon Customer',
#  'Karan Nagwekar',
#  'Onya K',
#  'Akshay kg',
#  'Abs Kul ',
#  'ZOHAIB HASAN',
#  'VAIBHAV RATHORE',
#  'Bittu',
#  'Madhurima Basu',
#  'RAHULJangra']

# %%
len(cust_name)
# Out:
# 60

# %%
for j in range(0,6):
    cust_name.pop(0)
    cust_name.pop(0)
print(cust_name)
len(cust_name)
# Out:
# ['Digidoty', 'Amazon Customer', 'Digidoty', 'Shopaholic🆗', 'Amazon Customer', 'AS Peterson', 'Rahul', 'Sameer Patil', 'Shashank ', 'aryanshah', 'Dr. Rakesh Jain', 'ABHINANDAN', 'Digidoty', 'Amazon Customer', 'Amazon Customer', 'God', 'ravinder yadav', 'Rishabh Tiwari', 'Varifree', 'AMANJOT SINGH', 'Hardik Thakkar', 'Amazon Customer', 'Jaykumar Hankare', 'K Santosh', 'Digidoty', 'Amazon Customer', 'Ashutosh Mishra', 'HD', 'Aman Sharma', 'Roshan Kumar', 'Syed Amaan Akhtar', 'S', 'Ghalib', 'Gaurvendra Yadav', 'The Mango Couple', 'Shihab.H', 'Digidoty', 'Amazon Customer', 'Amazon Customer', 'Karan Nagwekar', 'Onya K', 'Akshay kg', 'Abs Kul ', 'ZOHAIB HASAN', 'VAIBHAV RATHORE', 'Bittu', 'Madhurima Basu', 'RAHULJangra']
# 48

# %%
print(len(cust_name))
print(cust_name)
# Out:
# 48
# ['Digidoty', 'Amazon Customer', 'Digidoty', 'Shopaholic🆗', 'Amazon Customer', 'AS Peterson', 'Rahul', 'Sameer Patil', 'Shashank ', 'aryanshah', 'Dr. Rakesh Jain', 'ABHINANDAN', 'Digidoty', 'Amazon Customer', 'Amazon Customer', 'God', 'ravinder yadav', 'Rishabh Tiwari', 'Varifree', 'AMANJOT SINGH', 'Hardik Thakkar', 'Amazon Customer', 'Jaykumar Hankare', 'K Santosh', 'Digidoty', 'Amazon Customer', 'Ashutosh Mishra', 'HD', 'Aman Sharma', 'Roshan Kumar', 'Syed Amaan Akhtar', 'S', 'Ghalib', 'Gaurvendra Yadav', 'The Mango Couple', 'Shihab.H', 'Digidoty', 'Amazon Customer', 'Amazon Customer', 'Karan Nagwekar', 'Onya K', 'Akshay kg', 'Abs Kul ', 'ZOHAIB HASAN', 'VAIBHAV RATHORE', 'Bittu', 'Madhurima Basu', 'RAHULJangra']

# %%
title=[]
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("a",{'data-hook':"review-title"}):
            title.append(i.text)
# Out:
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=10
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=11
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=12
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=13
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=14
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=15
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=16
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=17
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=18
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=19
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=20
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=21
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=22
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=23
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=24
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=25
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=26
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=27
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=28
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=29
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=30
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=31
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=32
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=33
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=34
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=35
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=36
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=37
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=38
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=39
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=40
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=41
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=42
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=43
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=44
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=45
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=46
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=47
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=48
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=49

# %%
review_title=[]
for i in range(0,len(title)):
    review_title.append(title[i])
review_title[:]=[titles.lstrip('\n') for titles in review_title]
review_title[:]=[titles.rstrip('\n') for titles in review_title]
review_title
# Out:
# ['Loved this Mic',
#  'BEST BUDGET BUY-BOYA MIC',
#  'BEGINNERS DONT BUY USE YOUR HEADPHONES INSTEAD',
#  'Worst mic',
#  'Honest Review: A must have for all audio junkies',
#  'DETAILED REVIEW with Best settings for better Sound output !!!',
#  'Noise cancellation is not supportive in this mic',
#  "Just don't buy this mic, youtube reviews are fraud, mic quality is muffled read my review",
#  'Poor Quality and No After Sales Support.',
#  'BEST BUDGET MIC FOR RECORDING',
#  'Loved this Mic',
#  'BEST BUDGET BUY-BOYA MIC',
#  'BEGINNERS DONT BUY USE YOUR HEADPHONES INSTEAD',
#  'Worst mic',
#  'Honest Review: A must have for all audio junkies',
#  'DETAILED REVIEW with Best settings for better Sound output !!!',
#  'Noise cancellation is not supportive in this mic',
#  "Just don't buy this mic, youtube reviews are fraud, mic quality is muffled read my review",
#  'Poor Quality and No After Sales Support.',
#  'BEST BUDGET MIC FOR RECORDING',
#  'I Got FAKE Mice',
#  "It's okay. But not so good for the price.",
#  'Boya best mic ever',
#  'No noise cancellation',
#  'Product is possibly not up to mark',
#  "Don't buy",
#  'Boya Mike stopped working just in a Week',
#  'No Noise Cancellation',
#  'Nice..',
#  '(Edited )Worst /good experience ever.. RECORDS POOR LOW NOISEY AUDIO.',
#  'Detailed review read to know everything',
#  "Don't buy this",
#  'Not a paid review, This mic is worst even if you get it under ₹300',
#  'Honest Review :  (3.8★)',
#  'Just go for it..',
#  "Doesn't work for Laptops!",
#  'REAL MIC. GREAT NOISE CANCELLATION',
#  'Read my complete review before buying.... Boya is not for mobile and not for newer....',
#  'Must have mic for beginners and outdoor video makers',
#  'Echo !  Test before buy for PC or voice recognition',
#  'Fake product. DO NOT BUY',
#  'EH.',
#  'Low price! No QR code though! Original or not? But it WORKS.',
#  '"DUPLICATE BOYA MY-M1 MIC ALERT"',
#  "There's no match to Boya when it comes to lavelier mic. Best in the market!",
#  'Very very good for beginners',
#  'Yes its a Lavalier Lapel Category Mic',
#  'Nice Product',
#  'Best Lapel for recording',
#  '4star product',
#  'A high class microphone.',
#  'Misplaced Stickers inside the battery cabin',
#  'Loved it !😍😇',
#  'not so good for my desktop',
#  'Not Compatible For Every mobile Phones',
#  'Worst experience.',
#  'Read this before you buy, value for money',
#  'Extremely poor quality. Will return it.',
#  'Best Lav Mic on Budget.',
#  'Think before you buy,was not compatible with Canon 200d Mark 2,they replaced me with a working one',
#  'Bought twice....turned out trash both the times.',
#  'Extremely poor quality',
#  'Superior to the mic on the Sony a6400 but no noise cancellation',
#  'Best Mic for YouTubers ?',
#  'Good sound capture',
#  'Unbelievable mic in this price range!',
#  'Great mic for basic recording',
#  'Not as good as many YouTubers have reviewed it',
#  'You need a technical trail and error run to learn usage',
#  'Not for Beginners',
#  'This mic is legendary',
#  'The WORST Product i ever purchased in Amazon',
#  'Packing was wet but product is intact and working perfectly.',
#  'The little champ',
#  'Excellent for YouTube and casual recordings',
#  'Good But...',
#  "Don't buy for laptop. You may buy it for DSLRs.",
#  'Best budget mic for beginners and content creators',
#  'Not happy with it, actually i am annoyed by it',
#  'I received fake product.',
#  'Value for money..',
#  'Noise cancellation (disliked) , overall (Best)',
#  'I would buy again',
#  'Worst noise cancellation and quality',
#  'Youtube misguided. It works with certain apps only',
#  'Fake product',
#  'A very good mic for recording interviews',
#  'Works with (Linux) UBUNTU 18.04 too. Use with Battery installed, and switch on Camera Mode.',
#  'Defective Product Received',
#  'Be careful, Does not work with PC or laptops with an old mic slot(TRS)',
#  'Okay Product',
#  'Worst product',
#  'Very good microphone. Read my review.',
#  'Zero Noise Cancellation, adds no value',
#  'Expected little more',
#  'Worth it and best',
#  'Did not work for me',
#  'NO NOISE CANCELLATION, CAPTURES ALL BACKGROUND SOUNDS',
#  'Well here what you need before buying it for pc',
#  'Slight continuous hissing sound',
#  "If you are new to career it doesn't require to buy this product just save your money",
#  'The battery power is unreliable.',
#  'Suitable for beginners / silent locations',
#  'Best Product',
#  'Decent microphone for beginners',
#  'Its good! Hopefully☺️',
#  'Catches noise from surrounding',
#  'Damaged product...',
#  'Do not waste your money',
#  'Very  good material at this price.',
#  'The battery once installed , it cannot be removed easily',
#  'Speechless about the product in this price range.',
#  'FAKE....FAKE.....FAKE...!!!',
#  'Great quality!',
#  'Really amazing Mic! Here is all you need to know about this product!',
#  'Superb sound for presentation and video recording',
#  'Awesome Mic',
#  'Great quality mic',
#  'Good!',
#  'Great product but TOOO MUCH OF WIRE and wires are of not good quality',
#  'Great for the price. Does the job well. Good packaging.',
#  'I need QR code for security check. QR code is missing.',
#  'This is FAKE MIC.',
#  "Don't buy it won’t last long",
#  'Its good.',
#  "If it's for less than Rs.800, they're selling you the used one.",
#  'Problem with ribbon',
#  'A good lavalier microphone.',
#  'Awesome as always',
#  'Great product at affordable price',
#  "doesn't work with all phones(inbuilt camera app)",
#  'Nothing could have been better value than this Mic',
#  'Bestest product',
#  'No difference in sound',
#  'Worthy',
#  'Very Good Product ..',
#  'Good quality Microphone For Begginers',
#  'Not recommended for Singers/Musicians',
#  'Must go through my review 🙏🙏',
#  'वेल्यु फॉर मनी प्रोडक्ट',
#  "Laptop speakers don't work when plugged in",
#  'Not working',
#  'Not to be used with Piano/Keyboard/Synthesizer',
#  'Excellent..!!',
#  'Superb Product and Good Deal by amazon',
#  'Quality and Comfort',
#  'Best microphone for smartphones with superb sound quality',
#  'Great product and 100% genuine.',
#  'Very Good, Excellent Recording, Easy to Use',
#  'Awesome Mic',
#  'This is best mic at this price range',
#  'Fake fake fake',
#  'For beginners.',
#  'WORTH EVERYY PENNY!',
#  'Good product',
#  'Marvellous Mic',
#  'Good purchase ! Read it before you buy!!!',
#  'Passive recording great, but, powered mode not so',
#  'Good but not useful due to its limitation.',
#  'Fake product',
#  'Very good product at the price offered, very satisfied with it!',
#  'Not bad but good',
#  'Very good product',
#  'Awesom product at cheap price',
#  'Sound Quality, Noise Cancellation & Carry Bag',
#  'Mic is perfect for Beginners',
#  'Value for money',
#  'Beginners mic',
#  'TRRS to TRS',
#  'Fake Product... New users keep cautious!!!',
#  'Fake product',
#  'Below average',
#  "It's just Amazing",
#  'Best mic for recording youtube videos',
#  'good ,as expected.',
#  'Best mic for Youtuber',
#  'Product is waste!!',
#  'This QR code is show any product for boya mic is duplicate mic',
#  'Highly recommended',
#  'Le lo fr maja ayega.😂',
#  '🤞JUST GO FOR IT🤞 SOUND LIKE A PRO🤙',
#  'nice mic',
#  'Not working at all',
#  'Great package, bad show',
#  'Absolutely best mic in this price segment',
#  'Below average',
#  'All important details.🍁',
#  'I got first copy coz Logo of boya & authentic sticker was not there.',
#  'Best lapel mic for youtubers and online classroom.',
#  'Duplicate product',
#  'Works well but...',
#  'Boya BY-M1 is a winner for sure!',
#  'Good product',
#  'Good for beginners... Sound quality is really good.',
#  'Fake product: read the description carefully!',
#  "Read my feedback if you wanna be gamer it'll help you to choose right thing",
#  'Yes its the best under 1K',
#  'Good for beginners',
#  'Great budget device',
#  'Amazing sound quality..go for it',
#  'Great value for money',
#  'Very good Mic',
#  "Don't think much; Go and buy it.",
#  'Very good quality mic',
#  'Disappointed',
#  'Great Mic',
#  'Awesome for beginners.',
#  'Mic does not work',
#  '👎👎👎',
#  'A very fine product',
#  'Be aware of FAKE product ⚠️⚠️⚠️⚠️⚠️⚠️',
#  'Honestly written this review.. You can read before buying any lavalier mic..',
#  'Real good mike. Noise cancellation is very good.',
#  'Good Product for Beginer',
#  'Looks like duplicate',
#  'Best Budget Lavleir Microphone',
#  'Five 🌟 🌟 star',
#  'it is perfect for begginers but need to be used carefully.',
#  'Not take this microphone poor quality and not worth it',
#  'Excellent Build Quality',
#  "Only cracking sound is hearing and my voice can't be heard",
#  'Worst experience',
#  'Received used product',
#  'Noise cancellation is worse',
#  'Rip off !',
#  'do not work while video recording with mi max',
#  'Not Compatible with dell laptop',
#  'Product and sound quality is good but the noise cancellation is only satisfying',
#  "It's a good mic when compared with it's price.",
#  'Bought 3 times but still did not get Genuine Product',
#  'Good Product but Overhyped by YouTubers',
#  'Nice product',
#  'Impressed in first look but disappointed after opening. Exchanged one is old manufactured item.',
#  'Decent but not an extraordinary microphone.',
#  'GooD for 1000₹ Price range',
#  'Zaaakaaas !',
#  'no cancellation background noise its very bad',
#  'Go for some other Mike which will work on your mobile phone.',
#  'Decent product for beginners at this price range',
#  'Wotst chinese product',
#  'its not bad',
#  'Avoid it, not a better substitute of handsfree mic.',
#  'Best for beginners but not good for noise cancelling',
#  'Value for money!',
#  'helping me a lot',
#  'Probably the best budget Mic for Youtubers',
#  'No Noise Cancellation',
#  'Versatile and great for Social Media',
#  'Diffective item recieved from amazon...Not working...',
#  'Great for voiceovers and video recording.',
#  'Excellent',
#  'Noice cancellation not working properly',
#  'BEST SOUND AMPLIFIER',
#  'Pretty disappointed',
#  'Good on first day, gets worse every consequtive day.',
#  'Just go for it!',
#  'Does it worth?',
#  'Osm experience of youtuber',
#  'Great entry level mic.',
#  'Value for money. Excellent.',
#  'Shocking?',
#  'satisfactory,',
#  'Very bad and frustrated experience',
#  'No Noise cancellation and sound quality is also bad',
#  'It is better to use your mobile phone mic',
#  "Don't go for it.. genuine feedback",
#  'Really good at this price.',
#  'Laptop Users should read this review',
#  "Don't waste money",
#  'Superb microphone ...',
#  'Perfect for beginners and professionals.',
#  'Sides not work in smartphone',
#  'Best mic in this price range',
#  'there is no noise cancellation  - its an ordinary mic',
#  'Great Low cost Lapel Mic',
#  'Nice product , Just go for it.',
#  'Not working directly in smartphone, need third party app',
#  'Great Product for beginners',
#  "Best Quality microphone. Don't hesitate to buy.",
#  'Bad product experience',
#  'Very Poor Quality_Not Working',
#  'Worth every penny. Quality product...',
#  'Very good for the price',
#  'Great for YouTubr and others - but need more improvement',
#  'Low performance quality',
#  "it's not working at all",
#  'Best microphone for iPhone',
#  'Best in this price range 👍',
#  'Excellent audio quality and great noise cancellation',
#  'Noise cancellation',
#  'May be a duplicate one',
#  'Well product but bad packaging',
#  'Good product',
#  'Good microphone with long cable',
#  'great product',
#  'Not compatible',
#  'Phenomenal 🤩💯',
#  'Ok, not good',
#  'Worst product',
#  'Worst experience with amazon!!!',
#  'No Noise cancellation!  Sound ia superb!',
#  'Do not waste money',
#  'Very good for beginners',
#  'Got a waste of money item from amazon for the first time.',
#  'Its good with this price point.',
#  'If you want a tiny lav mic this is it, if you wanna sing, do vocals then get a regular mic.',
#  'Awesome product,',
#  'Worst product to buy i want to return it',
#  'A good purchase for regular use.',
#  'Mobile effecting after usage of 1 month Boya',
#  'Very good buy',
#  'Great build, great sound, might require audio gain',
#  'If you are buying for Noise Cancellation...',
#  'Unable to use for camera',
#  'Original Product from boya',
#  'Ok but think twice before purchasing.',
#  'Only for beginners',
#  'This product for new youtuber others kindly stayaway away',
#  "On android With default camera application it's not working",
#  'Its not working for my phone',
#  'Boya BYM1 Omnidirectional Lavalier Condenser Microphone with 20ft Audio Cable (Black) DOES NOT WORK.',
#  'Good for beginners',
#  'Product has not worked for me',
#  'Must have for beginners',
#  'No noise cancellation !!',
#  'A Chinese product not worth buying',
#  'In one line is not possible because unsatisfactory comments need to be mentioned',
#  'GO FOR IT. GOOD SOUND QUALITY',
#  'Best mic in affordable price',
#  'Fake or duplicate product',
#  'No return policy',
#  'Need refund in my pay balance',
#  'Not working... help me if you can...',
#  'Excellent product',
#  "Best for beginners and great investment, don't go with any other mic",
#  'Decent microhone, but depending on the device, you might need a small battery',
#  "It's not support to phone camera",
#  'Wrong product I choose',
#  'Not being detected on my laptop and pc',
#  'Expected better',
#  'Very nice and value for money.',
#  'Nice product',
#  'Damged product',
#  'Good one according to price',
#  'It stopped working after a month',
#  'Better to buy other mic',
#  "A mic which doesn't record",
#  'Not worthy. Did not work on laptop',
#  'the mic is very good',
#  'Not like YouTube reviews.',
#  'It does not open for battery',
#  'Best Mic in budget..👍👍👍👍',
#  'Not satisfied',
#  'Namma ooru kai manam YouTube channel',
#  'Worse',
#  'Not for your computer.',
#  'Record your surroundings except yours . I need new product from Boys & the seller.',
#  'Not suitable for Ahuja NBA PA20',
#  'Blindly go for it..',
#  'Good for beginners and sound recordings',
#  'This is not what you are looking for.',
#  'my boya m1 mic is not doing good at all',
#  'Ok Types',
#  'Product is good but packaging was worst (worstest)',
#  'Very Good',
#  'Good for Android but....',
#  'Nice mic for recording noise free audio. Good for vloggers.',
#  'Disappointed with the product. Bought it after watching YouTube reviews.',
#  "Don't buy, genuine review",
#  'A great mic!',
#  'Overall a nice mic',
#  'Does not work with OPPO K3',
#  'Best Mic for Beginner, Love it.',
#  'Not recommended for PPT',
#  'Excellent for beginners',
#  'Best bang for the buck microphone at a budget',
#  'Will be a perfect selection for any beginner',
#  'Worthless',
#  'Best in budget for beginner but before buy check your surrounding voice. Bcoz easly captured',
#  'Too noisy',
#  'Poor quality and it doest work at all. They had shipped defective piece',
#  'Worth every penny',
#  'Alternative if condenser mic',
#  'Broken but beautiful',
#  'NOT COMPATIBLE with REDMI Smartphones',
#  'Totally wast of money, very cheap product.',
#  'Doubt that I received duplicate product.',
#  'Not working in Smart Phones',
#  '"Worth it"',
#  'Use it and love this product',
#  'Good quality',
#  'After Using 2 months Boya By-M1',
#  'A collar mike for mobile and camera',
#  'A Genuine product.',
#  'No return policy',
#  'This is it...go for it!!',
#  'Fake product delievered',
#  'Boya BYM1 Omnidirectional Lavalier Condenser Microphone  is now supporting my Realme XT Phone',
#  'Not so terrific purchase but is good enough',
#  'Do Not Buy',
#  'Worth the price *_*',
#  'Great mic for zoom calls and videos',
#  'Not useful if you have any original headphone with mic',
#  'Must have for beginners',
#  'Indoor:Yes, Outdoor:No',
#  'Only worked for first 2 months.',
#  'Best for speaking and worst for singing',
#  'Best for beginners',
#  'Unuseful ,',
#  'Worth the money.. (not value for money)',
#  'Superb product',
#  'Worse product not working at all',
#  'Background Noice issue.',
#  'Mic was not work after 3rd or 4th attempts',
#  'happy with this product',
#  'Good',
#  'Best mic',
#  'Nice product withing this price range',
#  'Review from youtuber.',
#  'How to use it..',
#  'Value for money',
#  'Honest review trust me on this.',
#  'pDont buy Boya BYM1',
#  'Great',
#  'Boya bym1',
#  'The 3.5mm audio jack is got damaged not by physically.',
#  'This product is not for Content creators... Use only for Online classes',
#  'Good sound Quality of original boya m1(QR CODE VERIFIED) After Exchanged FAKE Poor Product.',
#  'Dont waste your 💰',
#  'Faulty piece',
#  'Mindblowing clarity',
#  "Overall it's good",
#  'Disappointed just disappointed',
#  'Good purchase',
#  'Good quality mike. Must buy ;)',
#  'Im a youtuber, a photographer and a doctor',
#  'Product Review',
#  'Best Mic for this Price',
#  'Budget mic',
#  'Boya M1 mic',
#  "Waste Of money ..no noise reduction ..Don't buy",
#  'Excellent budget mic, only wind noise cancellation',
#  'Quality Sound Output.',
#  'Best for mobile and Camera only',
#  'Okay type',
#  'Product is good but its costly on Amazon, I later on found it cheaper on Flipkart',
#  'Very bad product ...not supported',
#  'Budget Handy Mic',
#  'Not working',
#  'Read the Detailef Review',
#  'Fake',
#  'Good choice for beginners',
#  'Not worth the money',
#  'best mic in this price range for youtubers',
#  'Perfect for YouTube and Social Media Influence',
#  'Value for money product',
#  'Good one',
#  'trrs to trs adpator important if used with splitter',
#  'Super stuff',
#  'Dependability and longevity of the product',
#  "It's a steal, buy it",
#  'Best Mic under Rs 1K',
#  'Good one but does not work with type c port',
#  'Too much background noise',
#  'Reasonable quality product',
#  'Excellent microphone for the price!',
#  'Must buy',
#  'Very good for beginners.',
#  'Product not even working',
#  'Best noise cancellation.',
#  'bang for the buck',
#  'AWESOME, BUT BUZZING SOUND!',
#  'Usefull o',
#  'Not for noice cancelling on Android',
#  'Not able to connect with OnePlus 6T',
#  "Don't buy...",
#  'Need a Converter😒',
#  'Use OPEN CAMERA app with this in Android',
#  'Good for indoors',
#  'Cancels voice sharpness',
#  'Besttttttttestttttt mic ever',
#  'Hearing option should also be there with this.',
#  'Not satisfied with the product.',
#  'grt for beginners for doing voice overs',
#  'Fuddu Mic',
#  'Value for money',
#  'Boya BYM1 Mic 🎤',
#  'Best for Beginners YouTubers',
#  'Did not last long',
#  'Best Budget Microphone!',
#  "Don't buy it smartphone users",
#  "Duplicate Product Don't buy -Fraud seller",
#  'Waste of hard earned money',
#  'Nice',
#  'Good',
#  'Return this collar mic',
#  'Time waste product',
#  'Good quality',
#  'Great for new YouTuber',
#  'Genuine and Honest review']

# %%
reviews=[]
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"review-body"}):
            reviews.append(i.text)
# Out:
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=10
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=11
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=12
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=13
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=14
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=15
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=16
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=17
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=18
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=19
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=20
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=21
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=22
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=23
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=24
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=25
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=26
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=27
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=28
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=29
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=30
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=31
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=32
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=33
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=34
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=35
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=36
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=37
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=38
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=39
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=40
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=41
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=42
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=43
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=44
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=45
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=46
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=47
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=48
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=49

# %%
review=[]
for i in range(0,len(reviews)):
    review.append(reviews[i])
review[:]=[rev.lstrip('\n') for rev in review]
review[:]=[rev.rstrip('\n') for rev in review]

# %%
print(len(review))
review
# Out:
# 500
# ["  I would say this is the best available Mic in this price range. This mic can be connected to your DSLR, Smarthones, Laptops etc.Pros :1. Long Wire2. Sound Quality is really good and richCons :1. It will pick background noise, if you are in a noisy environment. But you can use RecForge 2 Audio Recorder App in your smartphone to Remove All The Noises.Apart from that, it's all gold. Go for it 😊",
#  "  Hi,So, after using this mic for about a month I am writing this review.I will give the most genuine review of this mic.So, let's begin. What does a beginner need?A budget-friendly mic yet gives the Best output. Right?BUILT QUALITY-Mic piece is very compact and handy to use. Given its compact size, it makes it convenient to carry anywhere you want-Cable/wire is extraordinarily long (6 meters). However, that's a great plus point. The long wire makes recording much easier and hassle-free-It has a Velcro for cable management. So, not a difficult task to keep the lengthy wire under control.-It weighs around 100gms-There are no batteries included-There's a switch ON/OFF button. While recording You need to switch to CAMERA MODE (Don't really know why its written camera)SOUND QUALITY-My recordings have improved considerably with this Mic and I am loving it.-Just one complaint I have. It captures a lot of airflow meaning I can hear a lot of air from my mouth in the final output. Even If I record anything while holding the mic from a considerable distance I can hear my breathing sounds.-Sound quality is loud enough and crisp.-It does capture my room's ceiling fan sound. So, I can hear that-- whoosh-- sound in the background when I am plugged into my earphones.-I record with the AC on and keep the fan switched off.Also, It comes with a handy pouch to keep your mic safe (yay).So, finally Best for production for a beginner like me because at this price it gives ample quality output.",
#  '  WHEN RECORDING ON PHONE OR LApTOP THE quality was the same as you get from a regular headphone. i watched review about this product on y..tube even on the technical guruji channel. its a marketing strategy i guess. these are useless microphones with no noise cancellation. i dont know about if you r using it on dslr but on fon or pc it will give no special output. same fan noise and all.RETURNED',
#  '  It stoped working Within 2 months . While recording in starting it record for few seconds then after that records nothing . You will hear nothing recorded through this mic . Worst Mic .My whole amount got wasted . Very dispointed .',
#  '  I will give my honest review on Boya M1. Read this full and i may help you clear your dilemma. If you need in depth review i have a review video on youtube. go to youtube . com / mobiletechpoint or search for "mobile tech point Boya M1" and you will find the review video. Audio for the Entire video has been recorded with Boya M1.1. I bought Boya M1 for 800 rupees. So this is a great pro mic for the price.2. first thing we notice is that the cable is 6 meters long which is super lengthy. So You have to be good in cable management. It is nice to see that battery unit is made of metal. If you use the mic with smartphones you don’t need a battery because the mic draws the power from the phone. But in case of dslr, you need to switch to camera mode. Good part of this mic is that it can connect with smartphones, tablets, pc, dslr’s  and external audio recorders like zoom h1n. That’s pretty awesome right?3. For the price we pay, this mic gives you excellent quality audio. Having a 6-meter cable can be an advantage or disadvantage, it depends on how you look at it. If you are using the mic with external recorder you don’t need a 6m cable, but if you are using the mic with a dslr camera and if you want to move around, it gives you all the freedom. The other only concern that you need to be aware of is, since there is no battery indicator you might want to carry an extra battery. If you are going to record something important which you don’t want to miss at all, put in a new battery and you will be fine.4. If you are into audio recording, then Boya M1 lavalier mic is a must have. Even if you have an external audio recorder or a condenser mic, get this mic as well. I am sure this will come in handy at some point of time.If you have any doubts, post a comment on my youtube video i will answer your query. Thanks. Buy this!',
#  '  NOTE :@ Its ready to go Mic, which doesn\'t need any sound card and can be plugged and used directly even with smartphones.* Has 3.5mm jack connector built in, you can use 1/4\' connector if needed.@ It has very Long cable which measures upto 20 feet, so note that.@ It has absolutely NO noise isolation and normal smartphone earphones does better job of noise reduction compared to them in STOCK condition, but with SIMPLE EDITING this mic works just fine ( Check the review below for detailed settings )There are literally thousands of review on this product, but NONE explained the best possible settings for it when used with smartphone with Audacity software, or even in general. So I took the risk of ordering it and it turned out to be nightmare right out of the box, as the sound output was worse than my smartphone earphones. So I went to search for best settings on amazon & other sources but in vain. Fortunately I myself in experiments found the solution and now its working just fine.First I am mentioning all the pros and cons considering the settings that I found and then listing those settings,PROS :-------1. Built quality of the complete mic and cable is good for the price given.2. Length of cable is insane (20 feet).* I personally didn\'t find it useful, as I use it with my smartphone which is just couple of feet below in my pockets, but for some users it can be very useful if using in rig setup with Camera.3. Has universal 3.5mm jack, which is handy.4. Its easy to use, just plug and play device, which doesn\'t need any sound card or external device to work.5. Has support for multiple device right from smartphones to DSLRs and computers.6. It comes with carry pouch which is very handy, since its a mess with such long cables.CONS :--------1. Biggest con is the sound quality right out of the box. Its just garbage quality and even normal ears can\'t bear the background noise collection, so forget about audiophiles. My normal smartphone\'s earphones record much better sound quality compared to this.2. Length of cable is way too much for me and I guess for many users. I think there should have being multiple option on length to choose from, as keeping 20 feet cable wrapped and hanging or in pocket while recording is not comfortable.3. It comes with a button cell for recording sound for devices other than smartphone and there\'s NO way to know whether the battery is dead or what\'s its charging level. Only way to check is by plugging it to a digital recorder or computer and test. So if you are carrying it with recorder which doesn\'t has playback feature or if you are in hurry and in case of dead battery to record all the sound, then only way to find that your efforts are in vain will be when you comfortably sit to edit it and trust me, its very frustrating ! I am mentioning, it as this scenario have happened with me once, hence I am very cautious about batteries now & use it with smartphones or digital recorders.4. I think price should have being couple of hundred bucks less, considering the sound quality.BEST SETTING USING AUDACITY SOFTWARE :===================================These are the settings when you record with smartphone or any other device and there are lots of background noises and you use Audacity software, which is Free !1. Open the software and open the audio file you recorded with this mic.2. Select entire audio clip and open "Effects" and then " DISTORTION "3. Start the playback of audio clip in the software, so you can listen to change in effects that you are about to make.4.Now select " Distortion Type " option on the top of box and select " Soft Clipping ".* or select " Hard Limiter " and do the settings as it sounds suitable to you.5. Take the "Clipping Level cursor to extreme Right end or so until you hear soft pleasant output.6. Adjust the "Make-up Gain" cursor little bit if needed, I keep it on 49.* Here you can select which ever type, which you feel is suitable for you.7. Now just click " APPLY ".8. N ...
#  "  I cannot record my voice properly, Noise cancellation is very bad even a small noise it capturing in the background.I have tried to return this product but as per policy I can't return it seems like I have wasted my money.",
#  "  You want a good mic for recording videos and doing voice overs to get on YouTube and try to search a good microphone for youtubers or for beginners and you end up getting this boya mic which costs somewhere in between 800 rupees to 2000 rupees the price may fluctuate a lot but you know what this product is useless, because I have used to different microphones from different companies and they both sounded a lot better and crisper done this in this microphone your voice sounds as it is enclosed in a box or something it doesn't has that Christmas or that clarity so just don't go and be fooled by the ratings and all and amazon's choice is something like that because it is not at all a good product I will rather suggest you to buy a normal generic condenser microphone in the range of 300 to 400 or and I can guarantee you that those Chinese microphones will sound much better than this boya microphone. do you remember that if you want that crisper and clear voice you need to have a condenser microphone because condenser microphones are the ones that creates that crispy sound and on the other hand if you go for a dynamic microphone which is not at all available for mobile phones those microphones will give you a lot noise free experience in which you will not hear any kind of noise from the background but the process to connect those microphones is a lot complicated and you have to connected with your laptop or computer why are using a Phantom power supply so it's completely a different thing but do remember that if you want to get a good quality sound id3 and go with a condenser microphone or a generic microphone and just don't buy this mic, one another major problem with this microphone is that you will get along a very long wire with this and believe me guys this why is not at all going to help you in any for the cases because it is going to mess your videos a lot and you will end up messing your wires, normal 1 metre to 2 metre wire will be enough for you and even if you want to increase that length you can do so so just by using a normal wire and cutting the existing wire of your microphone and just try to connect that normal wire and extending it to your desired lenght.I am repeating again not to buy this microphone as it costs a lot and it doesn't have that quality of sound.One good thing it has is that the the battery part is made up of metal that's it.",
#  "  Below average quality product. There are many excellent reviews of this item. Still I am not convinced for excellent rating. I want to report the quality issue to manufacturer of this item.Reported the problem to after sales of Boya. THERE IS NO AFTER SALE SERVICE. THE CLAIM OF ONE YEAR WARRANTY IS TOTALLY FALSE. BUYERS CAN PURCHASE THIS ITEM AT ONE'S OWN RISK AND WITHOUT EXPECTATION OF ANY AFTER SALES SUPPORT.I do not thinking, this boya mic is of any use. I purchased a Y splitter in Rs. 200/- and I can use any microphone including Boya By M1 (without using the switch et all) with very ease. A thoroughly misrepresented item. A simple Lapel mic with Y spliter is a far far better option then this very expensive and inconvenient Boya BY M1.",
#  '  Earlier, I was having a generic mic (₹117) but that has poor voice recording quality and short cable. I bought this Boya Mic to increase the quality of the recording and it does what it says. The voice quality is very good. Build quality is above average. The mic can be used with DSLR cameras. The mic has control panel attched to the cable which is powered by a LR series cell. You can switch between camera and mobile by a button. Overall the mic is great in terms of value for money and voice recording quality.Cons:1. The cable is extremely long and tangles very easily.2. The standard camera app may not support external mic so you can download third party app like open camera.',
#  "  I would say this is the best available Mic in this price range. This mic can be connected to your DSLR, Smarthones, Laptops etc.Pros :1. Long Wire2. Sound Quality is really good and richCons :1. It will pick background noise, if you are in a noisy environment. But you can use RecForge 2 Audio Recorder App in your smartphone to Remove All The Noises.Apart from that, it's all gold. Go for it 😊",
#  "  Hi,So, after using this mic for about a month I am writing this review.I will give the most genuine review of this mic.So, let's begin. What does a beginner need?A budget-friendly mic yet gives the Best output. Right?BUILT QUALITY-Mic piece is very compact and handy to use. Given its compact size, it makes it convenient to carry anywhere you want-Cable/wire is extraordinarily long (6 meters). However, that's a great plus point. The long wire makes recording much easier and hassle-free-It has a Velcro for cable management. So, not a difficult task to keep the lengthy wire under control.-It weighs around 100gms-There are no batteries included-There's a switch ON/OFF button. While recording You need to switch to CAMERA MODE (Don't really know why its written camera)SOUND QUALITY-My recordings have improved considerably with this Mic and I am loving it.-Just one complaint I have. It captures a lot of airflow meaning I can hear a lot of air from my mouth in the final output. Even If I record anything while holding the mic from a considerable distance I can hear my breathing sounds.-Sound quality is loud enough and crisp.-It does capture my room's ceiling fan sound. So, I can hear that-- whoosh-- sound in the background when I am plugged into my earphones.-I record with the AC on and keep the fan switched off.Also, It comes with a handy pouch to keep your mic safe (yay).So, finally Best for production for a beginner like me because at this price it gives ample quality output.",
#  '  WHEN RECORDING ON PHONE OR LApTOP THE quality was the same as you get from a regular headphone. i watched review about this product on y..tube even on the technical guruji channel. its a marketing strategy i guess. these are useless microphones with no noise cancellation. i dont know about if you r using it on dslr but on fon or pc it will give no special output. same fan noise and all.RETURNED',
#  '  It stoped working Within 2 months . While recording in starting it record for few seconds then after that records nothing . You will hear nothing recorded through this mic . Worst Mic .My whole amount got wasted . Very dispointed .',
#  '  I will give my honest review on Boya M1. Read this full and i may help you clear your dilemma. If you need in depth review i have a review video on youtube. go to youtube . com / mobiletechpoint or search for "mobile tech point Boya M1" and you will find the review video. Audio for the Entire video has been recorded with Boya M1.1. I bought Boya M1 for 800 rupees. So this is a great pro mic for the price.2. first thing we notice is that the cable is 6 meters long which is super lengthy. So You have to be good in cable management. It is nice to see that battery unit is made of metal. If you use the mic with smartphones you don’t need a battery because the mic draws the power from the phone. But in case of dslr, you need to switch to camera mode. Good part of this mic is that it can connect with smartphones, tablets, pc, dslr’s  and external audio recorders like zoom h1n. That’s pretty awesome right?3. For the price we pay, this mic gives you excellent quality audio. Having a 6-meter cable can be an advantage or disadvantage, it depends on how you look at it. If you are using the mic with external recorder you don’t need a 6m cable, but if you are using the mic with a dslr camera and if you want to move around, it gives you all the freedom. The other only concern that you need to be aware of is, since there is no battery indicator you might want to carry an extra battery. If you are going to record something important which you don’t want to miss at all, put in a new battery and you will be fine.4. If you are into audio recording, then Boya M1 lavalier mic is a must have. Even if you have an external audio recorder or a condenser mic, get this mic as well. I am sure this will come in handy at some point of time.If you have any doubts, post a comment on my youtube video i will answer your query. Thanks. Buy this!',
#  '  NOTE :@ Its ready to go Mic, which doesn\'t need any sound card and can be plugged and used directly even with smartphones.* Has 3.5mm jack connector built in, you can use 1/4\' connector if needed.@ It has very Long cable which measures upto 20 feet, so note that.@ It has absolutely NO noise isolation and normal smartphone earphones does better job of noise reduction compared to them in STOCK condition, but with SIMPLE EDITING this mic works just fine ( Check the review below for detailed settings )There are literally thousands of review on this product, but NONE explained the best possible settings for it when used with smartphone with Audacity software, or even in general. So I took the risk of ordering it and it turned out to be nightmare right out of the box, as the sound output was worse than my smartphone earphones. So I went to search for best settings on amazon & other sources but in vain. Fortunately I myself in experiments found the solution and now its working just fine.First I am mentioning all the pros and cons considering the settings that I found and then listing those settings,PROS :-------1. Built quality of the complete mic and cable is good for the price given.2. Length of cable is insane (20 feet).* I personally didn\'t find it useful, as I use it with my smartphone which is just couple of feet below in my pockets, but for some users it can be very useful if using in rig setup with Camera.3. Has universal 3.5mm jack, which is handy.4. Its easy to use, just plug and play device, which doesn\'t need any sound card or external device to work.5. Has support for multiple device right from smartphones to DSLRs and computers.6. It comes with carry pouch which is very handy, since its a mess with such long cables.CONS :--------1. Biggest con is the sound quality right out of the box. Its just garbage quality and even normal ears can\'t bear the background noise collection, so forget about audiophiles. My normal smartphone\'s earphones record much better sound quality compared to this.2. Length of cable is way too much for me and I guess for many users. I think there should have being multiple option on length to choose from, as keeping 20 feet cable wrapped and hanging or in pocket while recording is not comfortable.3. It comes with a button cell for recording sound for devices other than smartphone and there\'s NO way to know whether the battery is dead or what\'s its charging level. Only way to check is by plugging it to a digital recorder or computer and test. So if you are carrying it with recorder which doesn\'t has playback feature or if you are in hurry and in case of dead battery to record all the sound, then only way to find that your efforts are in vain will be when you comfortably sit to edit it and trust me, its very frustrating ! I am mentioning, it as this scenario have happened with me once, hence I am very cautious about batteries now & use it with smartphones or digital recorders.4. I think price should have being couple of hundred bucks less, considering the sound quality.BEST SETTING USING AUDACITY SOFTWARE :===================================These are the settings when you record with smartphone or any other device and there are lots of background noises and you use Audacity software, which is Free !1. Open the software and open the audio file you recorded with this mic.2. Select entire audio clip and open "Effects" and then " DISTORTION "3. Start the playback of audio clip in the software, so you can listen to change in effects that you are about to make.4.Now select " Distortion Type " option on the top of box and select " Soft Clipping ".* or select " Hard Limiter " and do the settings as it sounds suitable to you.5. Take the "Clipping Level cursor to extreme Right end or so until you hear soft pleasant output.6. Adjust the "Make-up Gain" cursor little bit if needed, I keep it on 49.* Here you can select which ever type, which you feel is suitable for you.7. Now just click " APPLY ".8. N ...
#  "  I cannot record my voice properly, Noise cancellation is very bad even a small noise it capturing in the background.I have tried to return this product but as per policy I can't return it seems like I have wasted my money.",
#  "  You want a good mic for recording videos and doing voice overs to get on YouTube and try to search a good microphone for youtubers or for beginners and you end up getting this boya mic which costs somewhere in between 800 rupees to 2000 rupees the price may fluctuate a lot but you know what this product is useless, because I have used to different microphones from different companies and they both sounded a lot better and crisper done this in this microphone your voice sounds as it is enclosed in a box or something it doesn't has that Christmas or that clarity so just don't go and be fooled by the ratings and all and amazon's choice is something like that because it is not at all a good product I will rather suggest you to buy a normal generic condenser microphone in the range of 300 to 400 or and I can guarantee you that those Chinese microphones will sound much better than this boya microphone. do you remember that if you want that crisper and clear voice you need to have a condenser microphone because condenser microphones are the ones that creates that crispy sound and on the other hand if you go for a dynamic microphone which is not at all available for mobile phones those microphones will give you a lot noise free experience in which you will not hear any kind of noise from the background but the process to connect those microphones is a lot complicated and you have to connected with your laptop or computer why are using a Phantom power supply so it's completely a different thing but do remember that if you want to get a good quality sound id3 and go with a condenser microphone or a generic microphone and just don't buy this mic, one another major problem with this microphone is that you will get along a very long wire with this and believe me guys this why is not at all going to help you in any for the cases because it is going to mess your videos a lot and you will end up messing your wires, normal 1 metre to 2 metre wire will be enough for you and even if you want to increase that length you can do so so just by using a normal wire and cutting the existing wire of your microphone and just try to connect that normal wire and extending it to your desired lenght.I am repeating again not to buy this microphone as it costs a lot and it doesn't have that quality of sound.One good thing it has is that the the battery part is made up of metal that's it.",
#  "  Below average quality product. There are many excellent reviews of this item. Still I am not convinced for excellent rating. I want to report the quality issue to manufacturer of this item.Reported the problem to after sales of Boya. THERE IS NO AFTER SALE SERVICE. THE CLAIM OF ONE YEAR WARRANTY IS TOTALLY FALSE. BUYERS CAN PURCHASE THIS ITEM AT ONE'S OWN RISK AND WITHOUT EXPECTATION OF ANY AFTER SALES SUPPORT.I do not thinking, this boya mic is of any use. I purchased a Y splitter in Rs. 200/- and I can use any microphone including Boya By M1 (without using the switch et all) with very ease. A thoroughly misrepresented item. A simple Lapel mic with Y spliter is a far far better option then this very expensive and inconvenient Boya BY M1.",
#  '  Earlier, I was having a generic mic (₹117) but that has poor voice recording quality and short cable. I bought this Boya Mic to increase the quality of the recording and it does what it says. The voice quality is very good. Build quality is above average. The mic can be used with DSLR cameras. The mic has control panel attched to the cable which is powered by a LR series cell. You can switch between camera and mobile by a button. Overall the mic is great in terms of value for money and voice recording quality.Cons:1. The cable is extremely long and tangles very easily.2. The standard camera app may not support external mic so you can download third party app like open camera.',
#  '  When I Checked it from BOYA web site. It is shown that this product is already SOLD means I got FAKE product. Anyway product is working well.',
#  "  Your browser does not support HTML5 video.\n\n\n  \xa0Hi, I read the other reviews of this mic on amazon, YouTube. Mostly all are good so, I decided to buy it.First time, an already opened box was delivered, so I asked for replacement. Amazon quickly replaced my product and I received a packed one this time.This mic is not at all good for the price. The sound recorded is bad and low quality. It appears to be recorded on cheap quality mic present in earphones. My normal Logitech USB headset mic is working better than this.About noise cancellation:Yes it is cancelling the noise. But it is very harsh. During noise cancellation, it also reduces the quality of original voice. And thus we get a low quality voice. Unfortunately there is no option to turn off noise cancellation.Recommendation:If we want quality, I would suggest go for a good quality headset. It's voice would be clearer than this.Cons:- Very harsh noise cancellation, which reduces quality of actual voice.- 20 feel cable is so long. (it is both a pro and a con)- A little on heavier side- Voice quality is not good.Pros:- 20 Feet cable- Comes with 5.5 adapter to plugin into amplifier and other instruments- Build quality is amazing- Comes with a clip and cushion.- Comes with a small pouch.- Can be used on a camera.- Noise cancellationI've decided to return the product.",
#  '  nice produt boya best mic ever with zero noise long wire nice packing and thx amazon same day delivery good packing',
#  '  It\'s better to record your audio with your mid range mobiles rather wasting money with it. Voice quality with my Oppo F9 Pro and even redmi 4 has better voice quality than this too big ghost machine. Actually it is too long to use comfortably and it is worthless due to no capability of noise cancellation.  Even it does not support system inbuilt camera as well. You will have to download "Open Camera" and in this case you will not be able to use AI skills of system cameras in this AI smartphone era.  My final verdict: Extremely suggested to avoid it and find any alternative option.',
#  '  This is a terrible product. Works little bit OK with iPhone but it is useless with all other phones. I am assuming the product is possibly defective. Asking for a replacement and will see if it is fine with other phones. Edit 1- The replacement product came in a damaged packaging. Suspect it won’t perform. This shows the kind of company that is selling it.',
#  "  This is totally garbage because after some months it would stop working, I bought one on May 2018 and now it suddenly get stopDon't waste money go for other one. None of the Youtubers are using it regularly",
#  '  I bought this boya Mike on 19th of June. I got delivery of this on 24th of June. I am writing this review very sincerely and truthfully that this boya stopped working literally after a week of use. In a week I barely used it for a day or two and I packed this boya in its cover. When after a week and when I got to know that the return policy has already got lapsed on 4th of July, I thought it could be power button problem.... but on replacing power button with new one I learned that it was not a problem of power button but my boya had literally stopped working and I was helpless cause I missed my return date as per return policy. I would be much thankful if amazon can look into this matter with a genuine concern. Plus I haven’t used it on rough and tough basis. I have cared much of this boya Mike. Kindly look into this matter. My review is not for defaming your product. My review is for expressing my bad experience. You Mike could be best for many but I am suffering from this bad experience. It would be a great help if you can look into this matter with genuine interest. 🙏',
#  '  I have bought this product for youtube video making but I have seen so many big youtuber reviews about this product.1st Mic received on 26th Aug. But when I record video by this mic noise was not getting cancel while My when I record same video in same atomshphere I wound My Ear Phone record much better then this mic.  I thought it may be technical issue or may be damage something in this mic so I replaced it.ON 27st Aug I found my 2nd mic but same issue happen as i told.Over waste of money product. This time I returned it.',
#  '  Nice..but no noise cancellation..',
#  "  Edited :# Got replacement. Working excellent with OPEN CAMERA app....Sorry for my negative review ..It's NOT working in mobile phone default CAMERA app.Working perfectly with OPEN CAMERA app.. you have to select audio input as external audio in open camera app settings. Then only it works ...Cons :-1) No return policy. Only replacement. I wasted all my money.2) Records very low voice and there is NO NOISE CANCELLING while recording videos with my mobiles.Your mobile without this records much better.3) NOT LOUD..VERY VERY LOW VOICE. NOISEY AUDIO.WORST PRODUCT.tried with Realme2pro and redmi note 7pro..Pro's :-1) What's the use of loooooong cable when it does NOT serve the purpose...",
#  '  This lavalier mic is good based on the price less than 850/-Everything you need to know about this mic...contents : Mic, Pouch, battery,clip,foam(Mic) or foam pop filtersound quality : 4.7/5  for indoor usage , 3.8 /5 for outdoor usageDoes it work with smartphone : Yes it does but you need to remember you can use it on voice recorder just by plugging it in...Video recording from smartphone : Few phones may work but many of them will not work (Android users)suggestion : If mic doesn\'t work when u recording video.. Install "Open camera" app from playstore and then change the mic setting to External mic optionwire length is too much you get little irritation if it gets wired within..important note... there is an option to select via knob 1. smartphones 2. camerawhen you\'re using mic with smartphone you dont need batteries to be placed in.. well you will be required to put battery if you connect this with DSLREnjoy this is a good product to go with',
#  "  I purchased this mic after recommendations and lot of review videos from number of YouTubers.Note that I bought this item when amazon just started delivery of non essential products.The mic came along with a battery (button cell). It stopped working within 2 days, I thought it has some problem but after replacing battery it started working.Now it's been less than 2 months this mic has stopped working completely even after changing the battery it doesn't work.The worst part is you don't have any customer service available in India where you can take this mic and repair or replace or claim your warranty. So technically the 1 year warranty is useless if something happens to your mic.If you really want to buy a mic go to a local shop and buy a better one which you can test first and then buy accordingly. I believe amazon sent me a mic that was previously returned by someone cause it was not working. It somehow worked for me for few days but not anymore.I regret my purchase. During this lock down period we are forced to purchase most of the things from online shopping services but they are least bother to provide us the quality product.",
#  "  Really disappointed with this product. My Redmi note 5 pro inbuilt dual mic performs way better than this one. If you are recording indoor, don't go for it. I have checked sample and filtered the sample in Audacity with noise reduction twice. The Sample from Redmi note 5 pro inbuilt mic had way more bass and clear with very little noise. On the other hand sample from Boya mic had no bass at all and lots of noise. The reviews saying, A ₹100 mic performs equally are true.",
#  "  1. We all have listen about it from youtuber , you can understand the politics.2.  I purchased 765 ( with ₹200 cashback wich given amazon so ignore while real review)It's not cheaper as it's normal quality .3.It works well in audiobut not video in redMi phone  howeverWorking well in Samsung phones  .3. Noice cancellation is just little bit as orginal samsung/other best phone works .4. Length is 20 feet ( 13 hand) is enough for shooting .5. I've not checked for camera but it has option and extra jack for that , hope will work but as I see it will be just normal not better one.Conclusion : If you are just starting your audio/ video production for online then you can buy but it's worth should not ne more than ₹400 .",
#  '  so before buying i was reading the comments like its not working blah blah...so here i wanna say about it . is that if you are using this boya mic for your mobile then you have to download the app open camera and enable the external mic option...second as i have purchased this for my Nikon D5600 the for a dslr you have to turn on the button on camera option on your micalso put your DSLR on manual settings...and enjoy the sharp clear sound like all other professional youtubers ....i got this mic today and i am Fully satisfied...',
#  "  Doesn't work with Laptops having integrated headset and microphone port. User manual says it works with switch in OFF position, but their website suggests keeping it in Camera position. Both ways, it does not work for laptops. The seller also doesn't accept returns.",
#  '  Your browser does not support HTML5 video.\n\n\n  \xa0This is real mic.You may scan the QR code that will take you directly to the official website of boya. You have to type the 16 digit code. Then they will confirm you,whether the mic is real. Best price is 649.Great noise cancellation. Other reviews may tell this duplicate...but it depends on your luck. I got a real one. Hope you too.',
#  '  As per image n description it will work with mobile but it doesn\'t work on phone camera. When I tried to find solution through YouTubers, they are suggesting "open camera app. My mob camera is very good but Open camera app reduces quality of good camera as I felt. Other suggested option is to buy TRRS to TRS converter. Why we will buy this? This should be given by Boya if they are writing that it will work with mobile. I bought two converter through amazon but didn\'t work. Converter cost was 250 to 450/ rs. This is also additional cost. This should be given by Boya. But important thing is that Boya has not been mentioned the need of this converter. I lost returning time due to these experiments of buying converter etc. which should be provided by Boya. I should buy Kodak because they are giving this solution n especially mentioned the required things in the description. This is my experience with Boya. Amazon should revise the description in e catalogue..',
#  '  Good to Go :1. If you are youtuber and videos are being shoot outdoors and from distance.2. For smartphone as well DSLR3. For hands free operation.4. Phone mic input is very poor.5. Want to use it for presentation.Not useful1. If you voice over your videos at closed atmosphere.2. You don\'t want wired mic.NOTE : As of Aug 2019, this mic not supported by OnePlus camera app while shooting videos. We have to use Third-party camera app like Open Camera to use this microphone. I am using Open camera and Camera MX with mic. Few recent video on our channel "TheMangoCouple" are voice overed with help of this mic.',
#  "  From the previous buyers, I read a lot of reviews before I buy this mic(Boya), Also I watched some 'unboxing' and 'comparison'  videos from Youtube. They were forcing me to buy this item. I didn't care few  negative reviews seriously.  unfortunately, Now I realizie It was not the item i searched for!.  For me, the purpose of this mic was 'voice to text ' (voice recognition). Let me tell you frankly,  I am seriously disappointed. I cannot use this item  for my business  because of the Echo and delay to transfer the voice to my PC. I found no way to customize the settings except the windows default audio settings. I found no problem with short length cabled mics. So I didn't changed the default settings.  Actually  I don't know the cause of this issue is the unusual length of the cable. or the battery of the mic  is not enough to provide necessary  electricity.  I spent Rs.822 for this item.  The packing, finishing of the item, delivery etc were good.  But all of them are waste as I am not able to use the item!  I am using a  64Bit, windows7 Professional PC, i3, 3.7Ghz,  4GB RAM.  My Advice: Try to see and check the mic Before buying it.",
#  "  This is the worst product I ever received . It is fake one . No noise cancellation . If you want to check then go to its official website there you will get one code according to your product . If both codes match then it is original if not then it is fake.In my case it didn't matched . They are fooling customers .Those who are reading this review its your  decision , I m just giving my feedback. I have returned that product in refund policy but did not get refund money till the  date. I have tried each and every way out but no result . Finally I am writing this review. I have tried to contact amazon customer care but their number is not working .After lots of struggle I succeeded to contact them  , that guy said I have initiated the process but still I did not received my money and again its in unreachable mode :)  I have dropped many mails to them but no reply.It just humble request if you are planning this for long run product / quality don't go with this you will also regret. Extremely unhappy . If you want good one go to their original website or try other good alternatives it will give you better result. I went through 2 months of period  to contact them (mail,calls) but no output .Very disappointing service.",
#  "  I expected great things from this thing when I bought it, especially because a lot of YouTube filmmakers I follow recommended it as the best cheap alternative.Sadly, the noise cancellation on this thing is non-existent. It will catch everything from the wind to random ambient noise. This is not what you want with a lav mic, that is supposed to capture only your actor's voice.I'm sure in a controlled setup this mic will do an excellent job catching the robustness of the voice. But even then, there will be some background noise you'll have to clean out. And that's just not the kind of utility you want.All in all, you really pay for what you get here.",
#  '  I needed it for my youtube videos, so i bought it!At first i was very doubtful whether it was an original product or fake because i got it for 800+ Rs.I watched a lot of youtube videos about boya mic because at first it didn\'t work with my phone camera or voice recorder, and i got to know that this usually happens and that you have to download some other apps. So i did, and it worked!Also, there were a lot of videos where the original or the fake boya mic had QR code in it, but mine did not have any! So i was anxious about that too. Instead what i had was "coat the boya logo on right with water, they disappear". It did disappear when i coated it with water.However in the original boya website i didn\'t find this water coating thing.. but I\'m just hopefully happy with the product because it worked. I even made a \'sweet toasts - ASMR video\' on youtube, you can check it out for the noise and all.Hope it helped. Thankyou.',
#  '  "DUPLICATE" Boya BY-M1 mic...In original box there\'s no registered (®️) trademark...The switch in the receiver get displaced also not working when the switch is flipped and in original receiver it has red and green tintThe audio quality is very poor 200rs ear phone records better quality than this... Don\'t by from "MSDJ RETAIL" sellerI hope everyone go through this before buying from this seller..Thank you',
#  "  Using this for multiple applications like YouTube videos, interviews and client calls. Amazing voice recording quality. What a versatile product! It can be used with phone or DSLR or laptop and what not. Got this product for a great price and there's no match to this mic's quality. This is an omnidirectional mic and can catch voice from all angles. This means this is best suited for indoor use. I've also used this on my terrace and still it didn't catch any wind noise. 20ft. long wire is way more than enough. The fit and finish is amazing. Kudos to Boya for this amazing product.",
#  '  If you want a better mic at lower price, and you had nothing better you must get this. I wanted to teach online and record lectures so i went for a dedicated mic. If your daily headphone mic or laptop on-board is not performing you must buy this mic.  As a beginner one must not invest in very costly microphone.I used it for a week and it is above my expectations.Some usage pointers:It has a switch that says:1. Camera2. off/smartphoneIf you are connecting the mic to a camera or laptop switch to option 1.If you are connecting the mic to your smart phone switch to option 2.Dont judge this mic too quickly. Before purchasing it see some demonstrations on YouTube.',
#  "  when you start speaking something on the Mic it catches only your voice and other surrounding vocies or atmospheric sounds get dumped out but as you stop speaking anything, it catches other sounds from enviornment too such as utensil cleaning noise in a Kitchen that could be 20 Metre away from the room you are sitting in or barking sound of a stray dog but all these noises are on a very very low pitch level and don't distract at all the listener. so i would prefer it for outside enviornment too and for internal premise surrounding too. its a best product in its price category wise. so just grab it today if you are getting it in price range of INR 750 to 850.",
#  '  Captures every detail. Quality is also good. You need a splitter to insert an earphone with the mic to get your sound feedback or to listen to the karaoke track you are recording with.It\'s given in description that the battery switch should be "Off" while using with a mobile as it takes power from the mobile itself. But actually you have to keep the switch "On" while using it with a mobile otherwise it won\'t record anything.The recording output is crisp, clear and loud enough. You don\'t need to speak loudly and the mic captures the voice from a fair distance also.The wire length is also sufficient and the quality of the material is also good.Overall a nice product !',
#  '  I am satisfied with the Sound quality.But Noise cancellation is not that great rather it catches sounds from outside very clearly.The cable is very long which Real good.Need not o shout when speaking just a simple whisper can catch properly so when you are singing or recording a video just Do it normally..And I received a carry pouch as well.There is another Plug I guess its for DSLR, as I am using my mobile so No need that.There is a Battery as well. But that one is needed if the mic is attached with DSLR or other device, if we are using Mobile NO NEED TO USE BATTERY...So its a Good one and g for it.',
#  '  Not as per expectation as described by all the Youtubers.A bit of noise can be felt..Quality is slightly above average.Build quality is good.Noise cancellation is average.Price is also average and par with quality.I didnt recommend this to professional YouTubers.',
#  "  Very high quality microphone having powered and unpowered switch usable for the almost all form of audio inputs. Power switch mode is for the cameras and other devices those require power input and non power switch mode is for the smartphones, PCs, Laptops etc. having inbuilt preamplifiers so that a powered input is not necessary.Accessories provided with the microphone reflect an overall quality that the manufacturer wants to provide to it's users of this microphone.It's a high sensitive but low gain microphone so as to maintain a very good audio quality.A good preamplifier if used with this microphone before final audio amplification certainly would give a very good quality audio desirable for recording or similar purposes.Considering it's price and other factors, I would definitely recommend this microphone to others.",
#  '  The item is working. But the item has some manufacturing defects. When I try to open the battery cabin, it was very tight. After some trial, I opened it but I saw some stickers are misplaced in it. I try to fix and closed the cabin. Then try to open it again, this time also I feel the same tight. After opening the cabin I removed the misplaced stickers. Now it smoothly open but the wires and battery cabin are open. So please ensure the quality in the manufacturing process of this device.',
#  "  Your browser does not support HTML5 video.\n\n\n  \xa0The response is absolutely amazing it is catching all the heavy sounds of my voice...also its omnidirectional which means it do picks sounds from all around and present it in a mono audio type yes you can't get the results in STEREO or above...its response its around 20hz to 20khz yes its true...I'm right now using it for regular recording. It do works well with phone and cameras...! But one thing you must be careful while purchasing is tht it definitely doesn't provide any kind of noise cancellation so if you r think to buy it for vlog or outside recording it may disappoint but you can treat the voice by editing it...so overall I'm completely satisfied and this product works very well...it'll record your voice very perfectly...!",
#  '  I bought it for my computer. It is better than non-battery mics but still not good for voice recording. I tried with my desktop it is giving some hmm sound (however that could be my motherboard problem), I tried with a USB sound card the clarity is better but the strengh is very weak. (I swithed on battery as for computers it does not work without switching on the battery). being disappointed I bought a Behringer U-PHORIA UMC22 audio interface (about 6000 rs) and connected though it but there is no improvement in sound throughput. If I increase the mic volume to 100% in behringer and 100% in computer then I get better throughput (bigger waves in audacity) but the recording is useless because of extreme noise. I connected to my android phone, the quality is slightly lesser than my inbuilt mic. However, it is working alright with my laptop (atleast better than non-battery mics) hence I am giving 2 stars.',
#  "  I have listen it from my friends and online videos that this mic is very good in performance with best noise cancellation and bought, but really not happy because it was not working in my phone I checked every phones available in my home but it was not compatible, it was not working in any of phone, even I used the open camera software but it doesn't worked. Please don't buy if you want to use in mobile phone. I wasted my time and money.",
#  "  Don't know what they have sent, purchased after read good review,but I am unlucky to have this product. My earphone records good audio than this piece, I have tried in oppo reno 2 and one+ 7T, non of the mobiles do support this mic, then what's the need of buying this piece.",
# ...
#  "  After reading good reviews i bought this one but disappointed.No Background noise reductionIphone internal microphone is better than this in some instance.it increase the bass of audio little bit but most important aspect is noise reduction that it can't do.I am returning this itemNot recommended.",
#  "  Honestly it is one of the best budget mics for the beginners. However, it can not cancel noise other than wind. Wind noise is cancelled by the mic wind cover. So that's a physical property. But there are no internal system to cancel other noises. But overall it is really good at the price and easy to use. Clips easily to anything. Also the long wire helps.",
#  '  It is perfect for beginners in Youtube and the people who frequently attend online meetings or programs. We could also add more quality by plugging the microphone to Adobe Audition.Overall it is a Good Product. Needs Battery change according to our usage. A good length of wire is provided so that we could connect easily at a distance.',
#  '  This mic best fits with the mobile devices. If you are looking for mic for screen recording in desktop or your Laptop, this mic is not best fit. In some computers this mic maynot work when you insert in and sound quality will be poor. So go for usb microphone for PC recordings.',
#  '  Although I just used once, but results are not as expected. This much sound quality i could have record with my earphones as well. No need to invest if you wants to make videos for youtube.',
#  "  Product is nice, captures decent voice quality but it captures a lot of noise it may be because of its sensitivity or maybe anything else. But overall the product is good. But I'm not very happy with Amazon service and pricing because I received it in more than 8 days and around 200 rupees costlier than Flipkart",
#  "  Worst quality, I'm using this mic in realme 2 and it doesn't support in all the mic settings....I used this mic in open camera too but still the condition is same ,it's not recording my voice ...very bad experienceIm returning this !!!",
#  '  Sound Quality Superb, Noise cancellation almost but can edit to cancel the noise background... But make sure to be in a acoustic room you will enjoy your recording ..Almost good for guitar recording if u prefer  for natural sound though it is a omnidirectional but best in its segment..For beginners its the best u can afford it..Highly recommended.',
#  "  It is not working in mobile phone. Tried in Motorola, samsung and one plus. Tried all permutation combination but didn't work. Unfortunately checked it after 11 days so can't even return.",
#  '  The only point to consider is while using this in phone with RecForge, though this is a LAV mic, try to keep it further away from your mouth for better experience and voice quality.While using with a laptop, you can keep it near to your mouth.Else the overall product is very very good.Has bought a drastic difference in my voice recordings on my channel',
#  "  It's working but it's fake when I checked using the id number given in the site it shows it's fake id number .I'm disappointed.n I will never buy electronic gadgets from Amazon I already stopped buying cosmetics cuz most of them are copy products",
#  "  Good for voice recording. Clear and crisp voice. Nice product in this price range for voice recording in slightly controlled environment. Not suitable for capturing wide field sound. Noise cancelling is not very high standard but you generally don't need for your regular use and gives you some feel of environment you are recording in. Overall its a nice choice for beginners in this price range.",
#  '  I dont know why they are so popular.  Could be because youtubers have made a hype of them.  For me,  they are not worth the price.  For those who are buying these just for recording using laptop.  I suggest not to waste money on them.  Most of the things are done by the software settings u r using for recording.Only ok for those who wants to give presentation and requires long wire.',
#  '  it is a good mic for youtubers it produce good sound but the problem is noise cancellation is not that great i mean when you record sound through this mic in a noisy place then the noise will be here in your recording but your sound will be clear with the noise.... i hope this will helpfull four you guys by the way i am also a gamer YouTuber and a tech youtuberhere is my channel name Gaming pro lucky',
#  "  Sound quality is perfect. If you are a social media influencer or a youtubers, don't wait to buy one. You can check my YouTube channel Swadisht Sardarji. The lastest video voice over part looks so nice compared to other videos of mine.",
#  '  I found it to be 50% better than Audio Technica lapel mic that costs more than double. Very good value for money product. I pair this with Zoom H1n field recorder to capture audio.',
#  "  They didn't mentioned that there is a small battery need to be installed before using this, Product head /Content managers need to mention this in the Product information.",
#  '  i like the product except for the fact that it must provide splitter which doesnot require trrs to trs adapter...or such adaptors must be kept in it',
#  "  No doubt its ever best mic that works superb with open camera app, plz note it might not work with some handset's but yes if you buy audio/mic splitter cable it will go well with any handset and do mind to switch ext mic settings provided in open app camera app video camera settings.",
#  "  The Omnidirectional Lavalier Condenser Microphone is good however it's not a dependable product. After about 50 days the mic has stopped working though the warranty on the product is one year it's not repairable. Buy the product as a matter of chance. In case it malfunctions there is no way to get it repaired though it may be in warranty period.",
#  "  Honestly, I was a lot sceptical about this when I placed the order.However,  it turned out to be actually a decent device. Noise cancellation truely works since it collect lesser ambient sounds. At under a 999 bucks it's a steal!",
#  '  This is the best microphone under Rs. 1kI bought this mic for youtube video recording and its works as expected.It can records voice very cleary.Built quality is also good.Noise cancellation is goodIn my opinion if anyone looking for mic under Rs. 1000 for youtube video recording then buy this product without any second thought.',
#  '  It does not work with my phone which has type c port. It works superb with other phone.no return option also only replacement.now i am thinking gifting it.',
#  '  It records very much background noise which effects voice clarity. If you are using it with DSLR then it becomes worst while for smartphone it is just OK OK.',
#  '  Excellent with i Mac / Adobe Audition software . Its working with my Ta-scam voice recorder too. Sound quality is really good and the extra ambient noise can be reduced in Audition easily. I recorded professional quality interview with this.',
#  "  I particularly like the fact that the battery doesn't come of use unless we are using it with a camera. It remains switched off for laptops and smartphones. The sound is also clear and crisp. I have had it for over three weeks now and it has been quite handy doing music and other recordings.  Highly recommend it for relatively good quality quick recordings.",
#  "  This mic is really awesome. If you are doing facecam video on mobile , only use open camera app don't use system camera app & if you are only voicing video without facecam so use kinemaster , noice cancellation is good if you attach mic on your collar , sound is loud most of the youtubers use this mic",
#  '  It will catch ceiling fan sound and also small sounds around you. You have to edit audio for noise cancelation. If you record in a sound proof room, it is very good.  The price is reasonable. Good for beginners. Go for it.  It is the best item at this price range.',
#  "  I bought this product..and this product is not working ..I check this with laptop and my mobile. But this product is not working.My request of exchange of this item also declined.I contact to Boya support.but didn't get proper reply.",
#  '  I like noise cancellation feature. If you are silent then this mic captures all noise but once you starts speaking the background noise suddenly disappears. It is cool this. I dislike one thing and that is long wire.',
#  "  My 5 star rating is taking the price into account. At this price, or even triple the price, there is nothing better. It doesn't work with iPhone, but that is not the product's fault. May work when used with a proper adapter. It works best with Android devices. Sound Quality and noise cancellation are impressive at this price.",
#  "  I've been using this mic for last 3 months and I've tried so many Boya Mic. The only one thing that has disappointed me every time is the buzzing sound. It always and automatically creates buzzing sound. I don't know what's the issue with this mic. But if anyone knows the solution please let me know. One more thing, It doesn't cancel any background noise.",
#  '  All the factors are good except the problem of noise Cancellation. In my point of view of you are showing your face while recording then you have purchase it but if you are not showing your face infront of the audience then you can simply record the audio from your cellphone.',
#  "  This mic give good sound quality on Android and pc but on Android there is nonoice cancelling but on pc you can use it with PC's inbuilt noice cancelling, I bought at 1250/-rs",
#  "  I have tried to connect it with my oneplus, some times it was done but most of the chances I couldn't. No clue is given regarding convection with OnePlus devices",
#  '  Recording from this mic is of no significance as compared to recording normally (without mic). No change in sound quality. Poor and Pathetic product.',
#  '  You should give TS port convertors also. There ports are not working in many of devices and then you have to purchase a trrs to trs convertor  which rarely anyone knows about. And above all you cannot return the product, you can only replace 🗡️',
#  "  The quality is just amazing, but if I pin it to my tee, you can hear disturbance.I prefer to keep it on my lap or the desk while recording YT videos.Use OPEN CAMERA app with Android if your normal camera isn't recognising the mic. Thank me later.",
#  '  Great for the price it is being sold atIf you need decent sound quality and good to look at mic, buy thisGood to record in close doors,Not recommended for noisy places!',
#  '  Waste product.  In the name of noise cancellation, it cancels the sharpness of the voice.  The product looks very nice but purpose is performance, there it lacks.',
#  '  I’m a influencer and youtuber. So I really need the best mic for making my videos. N finally I ordered. I just just loveeeeeee it. Love this mic. Voice comes really sharp. It literally hide background noise.',
#  "  The product is good as per quality is concerned but I was under the impression that hearing buds is also there with the mic. But it is not like that and that is why I want to return it. But I don't have option to return it, I just replace it with the same item. Request you to give me option to replace it with any other item of my choice.",
#  "  I did not find any improvement in sound quality as against the sound quality while directly recording through the phone. So i guess it's a waste of money and not worth the price.",
#  "  I make travel videos #sumitravelogs for my youtube channel and facebook page , so I needed this for voice over and its really nice; doesn't do noise cancellation much but good for beginners and can get connected to both pc and mobile phones.If you are reading this pls do follow n subscribe SUMITRAVELOGS, thanks and much love",
#  '  Pros:it just cheap as 800rslong wire"ba etna hi pros hai mere paas"cons:Noice bahut aati haiNot work with many phones eg.Honor PlayVoice recording is just like mobile rec.conclusion is, aggr app apne career k sth mzk kr rhe hai toh le wrna mt le, i will prefer ki koi 2-3000 ka achha mic le lo...',
#  '  The sound quality is extremely good for a 800 rupees mic .It is good enough for beginners to get started.There is no noise cancellation obviously it is just a 800 rupees mic.but you can use software cancellation.if you are using for video conference zoom has built in background noise reduction and if you want to record something u can use Dolby Access app for phone',
#  '  Quality of product with noise cancelation was good as per our expectation',
#  '  This microphone is best for beginners, i purchased it at 799 for making YouTube Videos. Noise cancellation is acceptable. Somehow you can do more noise cancellation on editing softwares. I generally prefer to remove noise digitally. You will not regret after buying this microphone.',
#  '  Mine did not last more than a month. I used it like 3-4 times overall. It was good till the time it worked but not reliable. Will not buy this mic again.',
#  "  I would say this is the best microphone for the price offered by Amazon. The sound quality on recording with this mic is amazing. If you have a budget and want to get a very good microphone, go with Boya BY-M1 you will never regret. It does it's job like an expensive high quality microphone would do. Thanks for this amazing product.",
#  "  Don't buy it smartphone users, specially beginners.its not working on smartphone Redmi mi note4.Ihave wasted my 2days for applying various tricks ie how to enable this mic on my mobile.I have seen so many videos on YouTube about how to use this on my phone,but unfortunately nothing has been work.total disappointment thinking of returning it..please think before it buying.",
#  "  Fake product.... No noise cancellation... Don't buy and waste money... Report against this seller. 700Rs waste.  Don't have any original code in this product",
#  "  This thing doesn't work with my laptop. The laptop somehow could not identify the port. It works with mobile phones though. However, my purpose was to use this with my laptop/desktop.Disappointed...Company should specifically mention this limitation on the product's description.",
#  "  Boya M1 mic is superb mic for beginners as well as for experts too with low budget YouTube vloggers. But only thing I don't like was we need to download external app for video recording n activating voice recording of BOYA M1. Or else this is the best mic. Please get the solution to work with the mobile inbuild app.",
#  '  The mic is good, and the sound quality is very awesome, noise cancellation is not that great, but we can mange, the product is as described, good quality',
#  '  I want to return this product... as it is not compatible to my mobile which is one plus 7 pro.....either i got to know how it would be compatible... otherwise this product is of no use of me...although i bought c-type audio jack to get it connected with my phone...but this collar mic is not working on my phone... pls return this item',
#  '  I could never understand when is it recording and when not.No provision to understand whether the voice is being captured or not.It was recommended to me by someone and before I could test it. The return time frame lapsed.Please do not buy until you have spare money to waste.I just have to throw it now and nothing else.',
#  '  Good quality happy with length and quality.  Only remember it will not work Direct on all phone camera.  I had to download open camera and it works well. So a good buy.',
#  '  If you are planning to shoot your own video for fun, or for social media then this should be your first choice. Go for it. Every next YouTuber uses this mic. Boya is great at this.',
#  '  Guys I wanted to start recording for normal YouTube Purpose, so ordered this after watching surreal videos from YT, but seriously it is just fine not that good, if you are totally beginner and go for it otherwise for main professional purpose i wont suggest you guys for this.']

# %%
ratings=[] 
for j in range(1):
    for k in range(pages):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("i",{'data-hook':"review-star-rating"}):
            ratings.append(i.text)
# Out:
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=10
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=11
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=12
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=13
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=14
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=15
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=16
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=17
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=18
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=19
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=20
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=21
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=22
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=23
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=24
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=25
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=26
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=27
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=28
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=29
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=30
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=31
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=32
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=33
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=34
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=35
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=36
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=37
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=38
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=39
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=40
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=41
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=42
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=43
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=44
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=45
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=46
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=47
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=48
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=49

# %%
rating=[]
for i in range(len(ratings)):
    rating.append(int(float(ratings[i].split(" ")[0])))

# %%
len(rating)
# Out:
# 500

# %%
upvotes=[]
for j in range(1):
    for k in range(10):
        response=Searchreviews(link[j]+'&pageNumber='+str(k))
        soup=BeautifulSoup(response.content)
        for i in soup.findAll("span",{'data-hook':"helpful-vote-statement"}):
            upvotes.append(i.text)
# Out:
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=0
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=1
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=2
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=3
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=4
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=5
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=6
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=7
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=8
# https://www.amazon.in/Boya-Omnidirectional-Lavalier-Condenser-Microphone/product-reviews/B076B8G5D8/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews&pageNumber=9

# %%
len(upvotes)
# Out:
# 71

# %%
import pandas as pd
rev={'TimeStamp':time,'ReviewTitle':review_title,'review':reviews,'ratings':rating} #converting the reviews list into a dictionary
review_data=pd.DataFrame.from_dict(rev) #converting this dictionary into a dataframe
review_data.to_csv('Amazon_product_data.csv',index=False)

# %%
df=pd.read_csv("Amazon_product_data.csv")
df.head(5)
# Out:
#                                TimeStamp  \
# 0  Reviewed in India on 24 November 2018
# 1      Reviewed in India on 25 July 2019
# 2        Reviewed in India on 8 May 2019
# 3    Reviewed in India on 5 October 2018
# 4  Reviewed in India on 14 February 2019
#
#                                         ReviewTitle  \
# 0                                    Loved this Mic
# 1                          BEST BUDGET BUY-BOYA MIC
# 2    BEGINNERS DONT BUY USE YOUR HEADPHONES INSTEAD
# 3                                         Worst mic
# 4  Honest Review: A must have for all audio junkies
#
#                                               review  ratings
# 0  \n\n  I would say this is the best available M...        5
# 1  \n\n  Hi,So, after using this mic for about a ...        5
# 2  \n\n  WHEN RECORDING ON PHONE OR LApTOP THE qu...        1
# 3  \n\n  It stoped working Within 2 months . Whil...        1
# 4  \n\n  I will give my honest review on Boya M1....        5

# %%
import pandas as pd
import numpy as np 
import spacy
import string 
import seaborn as sns
from nltk import PorterStemmer
from matplotlib.pyplot import imread
from matplotlib import pyplot as plt 
from wordcloud import wordcloud
from nltk.corpus import stopwords
# %matplotlib inline
import re
from textblob import TextBlob

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
def deEmojify(inputString):
    return inputString.encode('ascii', 'ignore').decode('ascii')

# %%
STOPWORDS=stopwords.words("english")

# %%
def clean_text(text):
    ps=PorterStemmer()
    
    text=deEmojify(text) # remove emojis
    text_cleaned="".join([x for x in text if x not in string.punctuation]) # remove punctuation
    
    text_cleaned=re.sub(' +', ' ', text_cleaned) # remove extra white spaces
    text_cleaned=text_cleaned.lower() # converting to lowercase
    tokens=text_cleaned.split(" ")
    tokens=[token for token in tokens if token not in STOPWORDS] # Taking only those words which are not stopwords
    text_cleaned=" ".join([ps.stem(token) for token in tokens])
    
    
    return text_cleaned

# %%
df['cleaned_reviews']=df['review'].apply(lambda x:clean_text(x))

# %%
df.sample(5)
# Out:
#                                  TimeStamp                      ReviewTitle  \
# 200   Reviewed in India on 3 November 2020            Great value for money
# 301    Reviewed in India on 15 August 2020               Do not waste money
# 33   Reviewed in India on 16 February 2020          Honest Review :  (3.8★)
# 304    Reviewed in India on 22 August 2020  Its good with this price point.
# 346   Reviewed in India on 14 October 2019       A mic which doesn't record
#
#                                                 review  ratings  \
# 200  \n\n  Records great sound. Long cable and very...        5
# 301  \n\n  Do not wate money. When connected to eit...        1
# 33   \n\n  1. We all have listen about it from yout...        4
# 304  \n\n  I am using last one month and it works w...        3
# 346  \n\n  I bought it after reading reviews but ev...        1
#
#                                        cleaned_reviews
# 200  \n\n record great sound long cabl conveni use ...
# 301  \n\n wate money connect either pc smartphonesy...
# 33   \n\n 1 listen youtub understand politics2 purc...
# 304  \n\n use last one month work well noth mind bl...
# 346  \n\n bought read review everyth glitter gold d...

# %%
from wordcloud import WordCloud
wordcloud = WordCloud(height=2000, width=2000, background_color='white')
wordcloud = wordcloud.generate(' '.join(df['cleaned_reviews'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common words in the reviews")
plt.axis('off')
plt.show()

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# %%
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# %%
df['Subjectivity']=pd.DataFrame(df.review.apply(lambda x: getSubjectivity(x)))

# %%
df['Polarity']=pd.DataFrame(df.review.apply(lambda x: getPolarity(x)))

# %%
df.head()
# Out:
#                                TimeStamp  \
# 0  Reviewed in India on 24 November 2018
# 1      Reviewed in India on 25 July 2019
# 2        Reviewed in India on 8 May 2019
# 3    Reviewed in India on 5 October 2018
# 4  Reviewed in India on 14 February 2019
#
#                                         ReviewTitle  \
# 0                                    Loved this Mic
# 1                          BEST BUDGET BUY-BOYA MIC
# 2    BEGINNERS DONT BUY USE YOUR HEADPHONES INSTEAD
# 3                                         Worst mic
# 4  Honest Review: A must have for all audio junkies
#
#                                               review  ratings  \
# 0  \n\n  I would say this is the best available M...        5
# 1  \n\n  Hi,So, after using this mic for about a ...        5
# 2  \n\n  WHEN RECORDING ON PHONE OR LApTOP THE qu...        1
# 3  \n\n  It stoped working Within 2 months . Whil...        1
# 4  \n\n  I will give my honest review on Boya M1....        5
#
#                                      cleaned_reviews  Subjectivity  Polarity
# 0  \n\n would say best avail mic price rang mic c...      0.420000  0.490000
# 1  \n\n hiso use mic month write reviewi give gen...      0.534783  0.328261
# 2  \n\n record phone laptop qualiti get regular h...      0.199725 -0.113095
# 3  \n\n stope work within 2 month record start re...      0.316667 -0.166667
# 4  \n\n give honest review boya m1 read full may ...      0.587568  0.332488

# %%
def sentiment_category(score):
    if score >= 0.05:
        return "positive"
    elif score <= -0.05:
        return "negative"
    else:
        return "neutral"

# %%
df['review_category']=df['Polarity'].apply(lambda x:sentiment_category(x))

# %%
df.sample(5)
# Out:
#                                  TimeStamp  \
# 383      Reviewed in India on 19 July 2020
# 305      Reviewed in India on 23 July 2020
# 245    Reviewed in India on 9 October 2018
# 499     Reviewed in India on 16 March 2021
# 80   Reviewed in India on 8 September 2020
#
#                                            ReviewTitle  \
# 383                               Broken but beautiful
# 305  If you want a tiny lav mic this is it, if you ...
# 245         Probably the best budget Mic for Youtubers
# 499                          Genuine and Honest review
# 80                                   Value for money..
#
#                                                 review  ratings  \
# 383  \n\n  The product was good I was so excited ca...        1
# 305  \n\n  If you need it for singing, vocals get a...        5
# 245  \n\n  I am using this from a few months. This ...        4
# 499  \n\n  Guys I wanted to start recording for nor...        4
# 80   \n\n  Everything looks gud and works fine in i...        4
#
#                                        cleaned_reviews  Subjectivity  \
# 383  \n\n product good excit caus posit review prod...      0.553704
# 305  \n\n need sing vocal get regular hand cardioid...      0.355342
# 245  \n\n use month best budget mic ever use great ...      0.388889
# 499  \n\n guy want start record normal youtub purpo...      0.575000
# 80   \n\n everyth look gud work fine initi test rec...      0.482500
#
#      Polarity review_category
# 383  0.260185        positive
# 305  0.243056        positive
# 245  0.357407        positive
# 499  0.181250        positive
# 80  -0.073333        negative

# %%
sns.countplot(df['review_category']).set_title("Distribution of Reviews Category")
# Out:
# Text(0.5, 1.0, 'Distribution of Reviews Category')

# %%
#positive reviews wordcloud
wordcloud = WordCloud(height=2000, width=2000, background_color='black')
wordcloud = wordcloud.generate(' '.join(df.loc[df['review_category']=='positive','cleaned_reviews'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common words in positive customer comments")
plt.axis('off')
plt.show()

# %%
#negative revies wordcloud
wordcloud = WordCloud(height=2000, width=2000, background_color='black')
wordcloud = wordcloud.generate(' '.join(df.loc[df['review_category']=='negative','cleaned_reviews'].tolist()))
plt.imshow(wordcloud)
plt.title("Most common words in negative customer comments")
plt.axis('off')
plt.show()
